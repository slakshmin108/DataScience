# %%
# File system commands
dbutils.fs.ls("dbfs:/") # list files in the root folder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: [FileInfo(path=&#39;dbfs:/FileStore/&#39;, name=&#39;FileStore/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/databricks-datasets/&#39;, name=&#39;databricks-datasets/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/databricks-results/&#39;, name=&#39;databricks-results/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/&#39;, name=&#39;mnt/&#39;, size=0)]</div>

# %%
dbutils.fs.ls("dbfs:/FileStore") # list files in the FileStore folder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [FileInfo(path=&#39;dbfs:/FileStore/shared_uploads/&#39;, name=&#39;shared_uploads/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/&#39;, name=&#39;tables/&#39;, size=0)]</div>

# %%
dbutils.fs.ls("dbfs:/FileStore/shared_uploads") # list files in the next subfolder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [FileInfo(path=&#39;dbfs:/FileStore/shared_uploads/lakshmi.srinivasan@integritymarketing.com/&#39;, name=&#39;lakshmi.srinivasan@integritymarketing.com/&#39;, size=0)]</div>

# %%
dbutils.fs.ls("dbfs:/FileStore/shared_uploads/lakshmi.srinivasan@integritymarketing.com") # list files in the next subfolder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [FileInfo(path=&#39;dbfs:/FileStore/shared_uploads/lakshmi.srinivasan@integritymarketing.com/male.wav&#39;, name=&#39;male.wav&#39;, size=816496),
#  FileInfo(path=&#39;dbfs:/FileStore/shared_uploads/lakshmi.srinivasan@integritymarketing.com/sample-1.txt&#39;, name=&#39;sample-1.txt&#39;, size=442),
#  FileInfo(path=&#39;dbfs:/FileStore/shared_uploads/lakshmi.srinivasan@integritymarketing.com/sample.txt&#39;, name=&#39;sample.txt&#39;, size=442)]</div>

# %%
import pyspark
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.unmount("/mnt/publicdrive") #unmount a drive if it already exists
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/publicdrive has been unmounted.
# Out[8]: True</div>

# %%
# Mount an Azure blob storage container to DBFS
dbutils.fs.mount(
  source = "wasbs://public2@blobstorage2021oct04.blob.core.windows.net",
  mount_point = "/mnt/publicdrive",
  extra_configs = {"fs.azure.account.key.blobstorage2021oct04.blob.core.windows.net":"EmKkdePytQ1Q9F4yKh5WU5Zea1ABmKeE7fMOOdy1PrpA8AS3ZvDYUO8Nnc633BiTWilJmQtzp0Jm5ZgWr2Ezlw=="})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: True</div>

# %%
dbutils.fs.ls("dbfs:/mnt") #list the mounts
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [FileInfo(path=&#39;dbfs:/mnt/publicdrive/&#39;, name=&#39;publicdrive/&#39;, size=0)]</div>

# %%
dbutils.fs.ls("dbfs:/mnt/publicdrive") #list the contents of the mount
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: [FileInfo(path=&#39;dbfs:/mnt/publicdrive/AnyDesk.png&#39;, name=&#39;AnyDesk.png&#39;, size=111592),
#  FileInfo(path=&#39;dbfs:/mnt/publicdrive/BUs.txt&#39;, name=&#39;BUs.txt&#39;, size=46),
#  FileInfo(path=&#39;dbfs:/mnt/publicdrive/sample.txt&#39;, name=&#39;sample.txt&#39;, size=442)]</div>

# %%
# Read a file from the mount
file = open("/dbfs/mnt/publicdrive/BUs.txt", "rt")
text = file.read()
print(text)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">PRE
# N&amp;F
# APL
# NEV
# AIM
# HIS
# PBG
# AIMC
# FFL
#
# </div>
